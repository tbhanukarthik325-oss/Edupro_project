# %% [markdown]
# # Conclusion
#
# - Successfully connected Python with MySQL.
# - Retrieved student data using SQL queries.
# - Performed Exploratory Data Analysis (EDA) using Pandas.
# - Visualized average marks, attendance, pass/fail ratio, and marks distribution using Matplotlib.
# - Found that 80% of students passed and 20% failed.
# - Kiran is the top-performing student based on total marks.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.hist(df["math"], bins=5)
plt.title("Distribution of Math Marks")
plt.xlabel("Math Marks")
plt.ylabel("Number of Students")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.bar(df["name"], df["attendance"])
plt.title("Student Attendance")
plt.xlabel("Students")
plt.ylabel("Attendance (%)")
plt.show()

# %%
df["Total"] = df["math"] + df["science"] + df["english"]

top_student = df.loc[df["Total"].idxmax()]

print("Top Performing Student:")
print(top_student)

# %%
result_count = df["result"].value_counts()

plt.figure(figsize=(5,5))
plt.pie(result_count, labels=result_count.index, autopct="%1.1f%%", startangle=90)
plt.title("Pass vs Fail")
plt.show()

# %%
import matplotlib.pyplot as plt

avg_marks.plot(kind="bar")
plt.title("Average Marks by Subject")
plt.xlabel("Subjects")
plt.ylabel("Average Marks")
plt.show()

# %%
avg_marks = df[["math", "science", "english"]].mean()
print(avg_marks)

# %%
df . describe()

# %%
df . info()

# %%
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="MyNewPassword123!",
    database="edupro_db"
)

df = pd.read_sql("SELECT * FROM students", conn)

df

# %%
import pandas as pd
import matplotlib.pyplot as plt
import mysql.connector
